# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [1,2,3,4,5]
y = [0.5,0.5,0.5]

# %%
z = np.convolve(x,y,mode='same')

# %%
z
# Out:
# array([1.5, 3. , 4.5, 6. , 4.5])

# %%
plt.plot(x)
plt.plot(z)

# %%
x = np.linspace(0,2*np.pi,100)
y = np.sin(x) + np.random.random(100) * 0.8
y_t = np.sin(x)+0.4

def smooth(y, box_pts):
    box = np.ones(box_pts)/box_pts
    print box
    y_smooth = np.convolve(y, box, mode='same')
    return y_smooth

plt.plot(x, y,'o')
plt.plot(x,y_t,'k')
#plt.plot(x, smooth(y,3), 'r-', lw=2)
#plt.plot(x, smooth(y,10), 'k-', lw=2)
plt.plot(x, smooth(y,19), 'g-', lw=2)
# Out:
# [0.05263158 0.05263158 0.05263158 0.05263158 0.05263158 0.05263158
#  0.05263158 0.05263158 0.05263158 0.05263158 0.05263158 0.05263158
#  0.05263158 0.05263158 0.05263158 0.05263158 0.05263158 0.05263158
#  0.05263158]

# %% [markdown]
# Check This Link : https://stackoverflow.com/questions/20036663/understanding-numpys-convolve
